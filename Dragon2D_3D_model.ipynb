# %%
# !pip install catboost BorutaShap

# %%
import pandas as pd
import numpy as np
import sklearn
import warnings
warnings.filterwarnings('ignore') # To suppress runtime and deprication warnings.

# %% [markdown]
# # Load Data

# %% [markdown]
# Data from https://github.com/cosylabiiit/bittersweet

# %% [markdown]
# Dragon3D data

# %%
# Load raw data.
bitter_train = pd.read_csv('manuscript - experiments/bitter-data/model-data-dragon_3d.tsv', sep='\t')
bitter_test = pd.read_csv('manuscript - experiments/bitter-data/gold-standard-dragon_3d.tsv', sep='\t')
sweet_test = pd.read_csv('manuscript - experiments/sweet-data/gold-standard-dragon_3d.tsv', sep='\t')
sweet_train = pd.read_csv('manuscript - experiments/sweet-data/model-data-dragon_3d.tsv', sep='\t')

# %%
print(bitter_train.shape)
print(bitter_test.shape)
print(sweet_train.shape)
print(sweet_test.shape)
# Out:
# (2135, 5096)
# (171, 5097)
# (2090, 5096)
# (154, 5097)

# %%
# Rename taste column as Target.
sweet_train.rename(columns={'taste':'Target'}, inplace=True)
sweet_test.rename(columns={'taste':'Target'}, inplace=True)
bitter_train.rename(columns={'taste':'Target'}, inplace=True)
bitter_test.rename(columns={'taste':'Target'}, inplace=True)


sweet_train.rename(columns={'smiles':'SMILES'}, inplace=True)
sweet_test.rename(columns={'smiles':'SMILES'}, inplace=True)
bitter_train.rename(columns={'smiles':'SMILES'}, inplace=True)
bitter_test.rename(columns={'smiles':'SMILES'}, inplace=True)

# %%
print(sweet_train.count())
sweet_train[sweet_train['SMILES'].isna()] # check if any of the SMILES is a NaN.
# Out:
# name            1993
# orig_taste      2090
# reference       2090
# SMILES          2090
# can-smiles      2090
#                 ...
# CATS3D_15_LL    2090
# CATS3D_16_LL    2090
# CATS3D_17_LL    2090
# CATS3D_18_LL    2090
# CATS3D_19_LL    2090
# Length: 5096, dtype: int64
# Empty DataFrame
# Columns: [name, orig_taste, reference, SMILES, can-smiles, Target, orig_idx, ITH, ISH, HIC, HGM, H0u, H1u, H2u, H3u, H4u, H5u, H6u, H7u, H8u, HTu, HATS0u, HATS1u, HATS2u, HATS3u, HATS4u, HATS5u, HATS6u, HATS7u, HATS8u, HATSu, H0m, H1m, H2m, H3m, H4m, H5m, H6m, H7m, H8m, HTm, HATS0m, HATS1m, HATS2m, HATS3m, HATS4m, HATS5m, HATS6m, HATS7m, HATS8m, HATSm, H0v, H1v, H2v, H3v, H4v, H5v, H6v, H7v, H8v, HTv, HATS0v, HATS1v, HATS2v, HATS3v, HATS4v, HATS5v, HATS6v, HATS7v, HATS8v, HATSv, H0e, H1e, H2e, H3e, H4e, H5e, H6e, H7e, H8e, HTe, HATS0e, HATS1e, HATS2e, HATS3e, HATS4e, HATS5e, HATS6e, HATS7e, HATS8e, HATSe, H0p, H1p, H2p, H3p, H4p, H5p, H6p, H7p, H8p, ...]
# Index: []
#
# [0 rows x 5096 columns]

# %%
print(sweet_test.count())
sweet_test[sweet_test['SMILES'].isna()] # check if any of the SMILES is a NaN.
# Out:
# name            154
# orig_taste      154
# reference       154
# SMILES          154
# can-smiles      154
#                ...
# CATS3D_15_LL    154
# CATS3D_16_LL    154
# CATS3D_17_LL    154
# CATS3D_18_LL    154
# CATS3D_19_LL    154
# Length: 5097, dtype: int64
# Empty DataFrame
# Columns: [name, orig_taste, reference, SMILES, can-smiles, In Bitter Domain, Target, orig_idx, ITH, ISH, HIC, HGM, H0u, H1u, H2u, H3u, H4u, H5u, H6u, H7u, H8u, HTu, HATS0u, HATS1u, HATS2u, HATS3u, HATS4u, HATS5u, HATS6u, HATS7u, HATS8u, HATSu, H0m, H1m, H2m, H3m, H4m, H5m, H6m, H7m, H8m, HTm, HATS0m, HATS1m, HATS2m, HATS3m, HATS4m, HATS5m, HATS6m, HATS7m, HATS8m, HATSm, H0v, H1v, H2v, H3v, H4v, H5v, H6v, H7v, H8v, HTv, HATS0v, HATS1v, HATS2v, HATS3v, HATS4v, HATS5v, HATS6v, HATS7v, HATS8v, HATSv, H0e, H1e, H2e, H3e, H4e, H5e, H6e, H7e, H8e, HTe, HATS0e, HATS1e, HATS2e, HATS3e, HATS4e, HATS5e, HATS6e, HATS7e, HATS8e, HATSe, H0p, H1p, H2p, H3p, H4p, H5p, H6p, H7p, ...]
# Index: []
#
# [0 rows x 5097 columns]

# %%
print(bitter_train.count())
bitter_train[bitter_train['SMILES'].isna()] # check if any of the SMILES is a NaN.
# Out:
# name            2057
# orig_taste      2135
# reference       2135
# SMILES          2135
# can-smiles      2135
#                 ...
# CATS3D_15_LL    2135
# CATS3D_16_LL    2135
# CATS3D_17_LL    2135
# CATS3D_18_LL    2135
# CATS3D_19_LL    2135
# Length: 5096, dtype: int64
# Empty DataFrame
# Columns: [name, orig_taste, reference, SMILES, can-smiles, Target, orig_idx, ITH, ISH, HIC, HGM, H0u, H1u, H2u, H3u, H4u, H5u, H6u, H7u, H8u, HTu, HATS0u, HATS1u, HATS2u, HATS3u, HATS4u, HATS5u, HATS6u, HATS7u, HATS8u, HATSu, H0m, H1m, H2m, H3m, H4m, H5m, H6m, H7m, H8m, HTm, HATS0m, HATS1m, HATS2m, HATS3m, HATS4m, HATS5m, HATS6m, HATS7m, HATS8m, HATSm, H0v, H1v, H2v, H3v, H4v, H5v, H6v, H7v, H8v, HTv, HATS0v, HATS1v, HATS2v, HATS3v, HATS4v, HATS5v, HATS6v, HATS7v, HATS8v, HATSv, H0e, H1e, H2e, H3e, H4e, H5e, H6e, H7e, H8e, HTe, HATS0e, HATS1e, HATS2e, HATS3e, HATS4e, HATS5e, HATS6e, HATS7e, HATS8e, HATSe, H0p, H1p, H2p, H3p, H4p, H5p, H6p, H7p, H8p, ...]
# Index: []
#
# [0 rows x 5096 columns]

# %%
print(bitter_test.count())
bitter_test[bitter_test['SMILES'].isna()] # check if any of the SMILES is a NaN.
# Out:
# name            115
# orig_taste      171
# reference       171
# SMILES          171
# can-smiles      171
#                ...
# CATS3D_15_LL    171
# CATS3D_16_LL    171
# CATS3D_17_LL    171
# CATS3D_18_LL    171
# CATS3D_19_LL    171
# Length: 5097, dtype: int64
# Empty DataFrame
# Columns: [name, orig_taste, reference, SMILES, can-smiles, In Bitter Domain, Target, orig_idx, ITH, ISH, HIC, HGM, H0u, H1u, H2u, H3u, H4u, H5u, H6u, H7u, H8u, HTu, HATS0u, HATS1u, HATS2u, HATS3u, HATS4u, HATS5u, HATS6u, HATS7u, HATS8u, HATSu, H0m, H1m, H2m, H3m, H4m, H5m, H6m, H7m, H8m, HTm, HATS0m, HATS1m, HATS2m, HATS3m, HATS4m, HATS5m, HATS6m, HATS7m, HATS8m, HATSm, H0v, H1v, H2v, H3v, H4v, H5v, H6v, H7v, H8v, HTv, HATS0v, HATS1v, HATS2v, HATS3v, HATS4v, HATS5v, HATS6v, HATS7v, HATS8v, HATSv, H0e, H1e, H2e, H3e, H4e, H5e, H6e, H7e, H8e, HTe, HATS0e, HATS1e, HATS2e, HATS3e, HATS4e, HATS5e, HATS6e, HATS7e, HATS8e, HATSe, H0p, H1p, H2p, H3p, H4p, H5p, H6p, H7p, ...]
# Index: []
#
# [0 rows x 5097 columns]

# %%
sweet_train['Target'] = sweet_train['Target'].astype(int) # Convert to numeric
sweet_test['Target'] = sweet_test['Target'].astype(int) # Convert to numeric

# %%
bitter_train['Target'] = bitter_train['Target'].astype(int) # Convert to numeric
bitter_test['Target'] = bitter_test['Target'].astype(int) # Convert to numeric

# %%
df_sweet_features_train = sweet_train[sweet_train.columns.difference(['name', 'orig_taste','reference','SMILES','can-smiles','orig_idx'])]
df_sweet_features_test = sweet_test[sweet_test.columns.difference(['name', 'orig_taste','reference','SMILES','can-smiles','orig_idx','In Bitter Domain'])]

# %%
bitter_test['reference'].unique()
# Out:
# array(['Phyto-Dictionary', 'Bitter-New', 'UNIMI'], dtype=object)

# %%
df_bitter_features_train = bitter_train[bitter_train.columns.difference(['name', 'orig_taste','reference','SMILES','can-smiles','orig_idx'])]


df_bitter_test_phyto = bitter_test[bitter_test['reference'] == 'Phyto-Dictionary']
df_bitter_test_bitternew = bitter_test[bitter_test['reference'] == 'Bitter-New']
df_bitter_test_unimi = bitter_test[bitter_test['reference'] == 'UNIMI']

df_bitter_test_phyto = df_bitter_test_phyto[df_bitter_test_phyto.columns.difference(['name', 'orig_taste','reference','SMILES','can-smiles','orig_idx','In Bitter Domain'])]
df_bitter_test_bitternew = df_bitter_test_bitternew[df_bitter_test_phyto.columns.difference(['name', 'orig_taste','reference','SMILES','can-smiles','orig_idx','In Bitter Domain'])]
df_bitter_test_unimi = df_bitter_test_unimi[df_bitter_test_unimi.columns.difference(['name', 'orig_taste','reference','SMILES','can-smiles','orig_idx','In Bitter Domain'])]

# %%
print(df_bitter_features_train.shape)
print(df_bitter_test_phyto.shape)
print(df_sweet_features_train.shape)
print(df_sweet_features_test.shape)
# Out:
# (2135, 5090)
# (88, 5090)
# (2090, 5090)
# (154, 5090)

# %%
df_sweet_features_train = df_sweet_features_train.drop('Target', axis=1)
df_sweet_features_test = df_sweet_features_test.drop('Target', axis=1)

df_bitter_features_train = df_bitter_features_train.drop('Target', axis=1)
df_bitter_features_test_pytho = df_bitter_test_phyto.drop('Target', axis=1)
df_bitter_features_test_bitternew = df_bitter_test_bitternew.drop('Target', axis=1)
df_bitter_features_test_unimi = df_bitter_test_unimi.drop('Target', axis=1)

# %%
df_sweet_features_train.apply(lambda x: pd.to_numeric(x, errors='coerce') )
mask_sweet_train = df_sweet_features_train.applymap(lambda x: isinstance(x, (int, float)))
df_sweet_features_train = df_sweet_features_train.where(mask_sweet_train)

df_sweet_features_test.apply(lambda x: pd.to_numeric(x, errors='coerce') )
mask_sweet_test = df_sweet_features_test.applymap(lambda x: isinstance(x, (int, float)))
df_sweet_features_test = df_sweet_features_test.where(mask_sweet_test)


df_bitter_features_train.apply(lambda x: pd.to_numeric(x, errors='coerce') )
mask_bitter_train = df_bitter_features_train.applymap(lambda x: isinstance(x, (int, float)))
df_bitter_features_train = df_bitter_features_train.where(mask_bitter_train)


df_bitter_features_test_pytho.apply(lambda x: pd.to_numeric(x, errors='coerce') )
mask_bitter_test = df_bitter_features_test_pytho.applymap(lambda x: isinstance(x, (int, float)))
df_bitter_features_test_pytho = df_bitter_features_test_pytho.where(mask_bitter_test)


df_bitter_features_test_unimi.apply(lambda x: pd.to_numeric(x, errors='coerce') )
mask_bitter_test = df_bitter_features_test_unimi.applymap(lambda x: isinstance(x, (int, float)))
df_bitter_features_test_unimi = df_bitter_features_test_unimi.where(mask_bitter_test)

df_bitter_features_test_bitternew.apply(lambda x: pd.to_numeric(x, errors='coerce') )
mask_bitter_test = df_bitter_features_test_bitternew.applymap(lambda x: isinstance(x, (int, float)))
df_bitter_features_test_bitternew = df_bitter_features_test_bitternew.where(mask_bitter_test)

# %%
X_train_sweet = df_sweet_features_train
y_train_sweet = sweet_train[['Target']]

X_test_sweet = df_sweet_features_test
y_test_sweet = sweet_test[['Target']]

X_train_bitter = df_bitter_features_train
y_train_bitter = bitter_train[['Target']]

X_test_bitter_pytho = df_bitter_features_test_pytho
y_test_bitter_pytho = df_bitter_test_phyto[['Target']] 

X_test_bitter_bitternew = df_bitter_features_test_bitternew
y_test_bitter_bitternew = df_bitter_test_bitternew[['Target']] 

X_test_bitter_unimi = df_bitter_features_test_unimi
y_test_bitter_unimi = df_bitter_test_unimi[['Target']]

# %%
print(df_bitter_features_train.shape)
print(X_test_bitter_bitternew.shape)
print(df_sweet_features_train.shape)
print(df_sweet_features_test.shape)
# Out:
# (2135, 5089)
# (27, 5089)
# (2090, 5089)
# (154, 5089)

# %%
# Print some metrics about the data.
print ("Total number of features: " + str(X_train_sweet.shape[1]))
print ("Total number of samples: "+ str(X_train_sweet.shape[0]))
print ("To check if there are any null values in the features and how many: ", \
       X_train_sweet.isnull().values.any(), X_train_sweet.isnull().sum().sum())
print ("To check if there are any null values in the target and how many:", \
       y_train_sweet.isnull().values.any(), y_train_sweet.isnull().sum().sum()) 
print ("The total number of Sweet targets: " + str(y_train_sweet[y_train_sweet.Target == 1].count()[0]))
print ("The total number of Bitter targets: " + str(y_train_sweet[y_train_sweet.Target == 0].count()[0]))
# Out:
# Total number of features: 5089
# Total number of samples: 2090
# To check if there are any null values in the features and how many:  False 0
# To check if there are any null values in the target and how many: False 0
# The total number of Sweet targets: 1126
# The total number of Bitter targets: 964

# %%
# Print some metrics about the data.
print ("Total number of features: " + str(X_train_bitter.shape[1]))
print ("Total number of samples: "+ str(X_train_bitter.shape[0]))
print ("To check if there are any null values in the features and how many: ", \
       X_train_bitter.isnull().values.any(), X_train_bitter.isnull().sum().sum())
print ("To check if there are any null values in the target and how many:", \
       y_train_bitter.isnull().values.any(), y_train_bitter.isnull().sum().sum()) 
print ("The total number of Sweet targets: " + str(y_train_bitter[y_train_bitter.Target == 1].count()[0]))
print ("The total number of Bitter targets: " + str(y_train_bitter[y_train_bitter.Target == 0].count()[0]))
# Out:
# Total number of features: 5089
# Total number of samples: 2135
# To check if there are any null values in the features and how many:  False 0
# To check if there are any null values in the target and how many: False 0
# The total number of Sweet targets: 728
# The total number of Bitter targets: 1407

# %% [markdown]
# # Preprocess

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_sweet = MinMaxScaler()
X_train_sweet_scaled = scaler_sweet.fit_transform(X_train_sweet)
X_test_sweet_scaled = scaler_sweet.transform(X_test_sweet)


scaler_bitter = MinMaxScaler()
X_train_bitter_scaled = scaler_bitter.fit_transform(X_train_bitter)


X_test_bitter_scaled_pytho = scaler_bitter.transform(X_test_bitter_pytho)

X_test_bitter_scaled_bitternew = scaler_bitter.transform(X_test_bitter_bitternew)

X_test_bitter_scaled_unimi = scaler_bitter.transform(X_test_bitter_unimi)

# %%
s_cols = X_train_sweet.columns
X_train_sweet_scaled = pd.DataFrame(X_train_sweet_scaled , columns = s_cols)
st_cols = X_test_sweet.columns
X_test_sweet_scaled = pd.DataFrame(X_test_sweet_scaled , columns = st_cols)

b_cols = X_train_bitter.columns
X_train_bitter_scaled = pd.DataFrame(X_train_bitter_scaled , columns = b_cols)
bt_cols = X_train_bitter.columns
X_test_bitter_scaled_pytho = pd.DataFrame(X_test_bitter_scaled_pytho , columns = bt_cols)
X_test_bitter_scaled_unimi = pd.DataFrame(X_test_bitter_scaled_unimi , columns = bt_cols)
X_test_bitter_scaled_bitternew = pd.DataFrame(X_test_bitter_scaled_bitternew , columns = bt_cols)

# %%
# Print some metrics about the data.
print ("Total number of features: " + str(X_train_sweet_scaled.shape[1]))
print ("Total number of samples: "+ str(X_train_sweet_scaled.shape[0]))
print ("To check if there are any null values in the features and how many: ", \
       X_train_sweet_scaled.isnull().values.any(), X_train_sweet_scaled.isnull().sum().sum())
print ("To check if there are any null values in the target and how many:", \
       y_train_sweet.isnull().values.any(), y_train_sweet.isnull().sum().sum()) 
print ("The total number of Sweet targets: " + str(y_train_sweet[y_train_sweet.Target == 1].count()[0]))
print ("The total number of Bitter targets: " + str(y_train_sweet[y_train_sweet.Target == 0].count()[0]))
# Out:
# Total number of features: 5089
# Total number of samples: 2090
# To check if there are any null values in the features and how many:  False 0
# To check if there are any null values in the target and how many: False 0
# The total number of Sweet targets: 1126
# The total number of Bitter targets: 964

# %%
# Print some metrics about the data.
print ("Total number of features: " + str(X_train_bitter_scaled.shape[1]))
print ("Total number of samples: "+ str(X_train_bitter_scaled.shape[0]))
print ("To check if there are any null values in the features and how many: ", \
       X_train_bitter_scaled.isnull().values.any(), X_train_bitter_scaled.isnull().sum().sum())
print ("To check if there are any null values in the target and how many:", \
       y_train_bitter.isnull().values.any(), y_train_bitter.isnull().sum().sum()) 
print ("The total number of Sweet targets: " + str(y_train_bitter[y_train_bitter.Target == 1].count()[0]))
print ("The total number of Bitter targets: " + str(y_train_bitter[y_train_bitter.Target == 0].count()[0]))
# Out:
# Total number of features: 5089
# Total number of samples: 2135
# To check if there are any null values in the features and how many:  False 0
# To check if there are any null values in the target and how many: False 0
# The total number of Sweet targets: 728
# The total number of Bitter targets: 1407

# %%
# remove punctuations in features names
import string
#sweet train
s_cols = X_train_sweet_scaled.columns
s_list = [''.join(char for char in item
                    if char not in ['[',']','<'])
            for item in s_cols]

#sweet test
st_cols = X_test_sweet_scaled.columns
st_list = [''.join(char for char in item
                    if char not in ['[',']','<'])
            for item in st_cols]


#bitter train
b_cols = X_train_bitter_scaled.columns
b_list = [''.join(char for char in item
                    if char not in ['[',']','<'])
            for item in b_cols]

#bitter test
bt_cols = X_test_bitter_scaled_pytho.columns
bt_list = [''.join(char for char in item
                    if char not in ['[',']','<'])
            for item in bt_cols]

# %%
X_train_sweet_scaled.columns = s_list
X_test_sweet_scaled.columns = st_list

X_train_bitter_scaled.columns = b_list

X_test_bitter_scaled_pytho.columns = bt_list
X_test_bitter_scaled_bitternew.columns = bt_list
X_test_bitter_scaled_unimi.columns = bt_list

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, average_precision_score , roc_auc_score , classification_report, f1_score, recall_score
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
def get_metrics(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:,1]

    print("Accuracy:",accuracy_score(y_test,y_pred))
    print("Precision:",precision_score(y_test,y_pred))
    print("Average Precision:",average_precision_score(y_test,y_pred_proba))
    try:
        print("AUROC:",roc_auc_score(y_test,y_pred_proba))
    except:
        print("AUROC: N/A (Only 1 class in y_true)")
    print("Sensitivity", recall_score(y_test, y_pred))
    print("Specificity", recall_score(np.logical_not(y_test),np.logical_not(y_pred)))
    print("F1-Score", f1_score(y_test, y_pred))
    print("Classification Report")
    print(classification_report(y_test, y_pred))
    print('-----------------\r\n')
    
def evaluate(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    get_metrics(model, X_test, y_test)

def evaluate_all(models, X_train, y_train, X_test, y_test):
    for model in models:
        print(f"Model: {model['name']}")
        evaluate(model['model'], X_train, y_train, X_test, y_test)

# %%
clf_xgboost_sweet = XGBClassifier(
    colsample_bytree=0.3,
    learning_rate=0.01,
    max_depth=10,
    n_estimators=1000
)
clf_catboost_sweet = CatBoostClassifier(
    depth=6,
    iterations=250, 
    learning_rate=0.2, 
    logging_level='Silent'
)
clf_rf_sweet = RandomForestClassifier(
    bootstrap=False,
    max_depth=None,
    max_features='auto',
    min_samples_leaf=1,
    min_samples_split=10,
    n_estimators=400
)
sweet_models_full = [
    {'model': clf_xgboost_sweet, 'name': 'XGBoost (No Feature Selection)'},
    {'model': clf_catboost_sweet, 'name': 'CatBoost (No Feature Selection)'},
    {'model': clf_rf_sweet, 'name': 'Random Forest (No Feature Selection)'},
]

# %% [markdown]
# # Sweet Classifier ( No Feature Selection)

# %%
evaluate_all(sweet_models_full,  X_train_sweet_scaled, y_train_sweet, X_test_sweet_scaled, y_test_sweet)
# Out:
# Model: XGBoost (No Feature Selection)
# Accuracy: 0.8051948051948052
# Precision: 0.9120879120879121
# Average Precision: 0.9462987062479548
# AUROC: 0.8752186588921282
# Sensitivity 0.7904761904761904
# Specificity 0.8367346938775511
# F1-Score 0.8469387755102041
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.65      0.84      0.73        49
#            1       0.91      0.79      0.85       105
#
#     accuracy                           0.81       154
#    macro avg       0.78      0.81      0.79       154
# weighted avg       0.83      0.81      0.81       154
#
# -----------------
#
# Model: CatBoost (No Feature Selection)
# Accuracy: 0.7792207792207793
# Precision: 0.8901098901098901
# Average Precision: 0.9443855366176224
# AUROC: 0.8744412050534498
# Sensitivity 0.7714285714285715
# Specificity 0.7959183673469388
# F1-Score 0.8265306122448981
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.62      0.80      0.70        49
#            1       0.89      0.77      0.83       105
#
#     accuracy                           0.78       154
#    macro avg       0.75      0.78      0.76       154
# weighted avg       0.80      0.78      0.79       154
#
# -----------------
#
# Model: Random Forest (No Feature Selection)
# Accuracy: 0.7857142857142857
# Precision: 0.9090909090909091
# Average Precision: 0.9479567485988556
# AUROC: 0.8783284742468415
# Sensitivity 0.7619047619047619
# Specificity 0.8367346938775511
# F1-Score 0.8290155440414507
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.62      0.84      0.71        49
#            1       0.91      0.76      0.83       105
#
#     accuracy                           0.79       154
#    macro avg       0.77      0.80      0.77       154
# weighted avg       0.82      0.79      0.79       154
#
# -----------------

# %% [markdown]
# # BItter Classifier (No Feature Selection)

# %%
clf_xgboost_bitter = XGBClassifier(
    colsample_bytree=0.3,
    learning_rate=0.01,
    max_depth=10,
    n_estimators=500
)
clf_catboost_bitter = CatBoostClassifier(
    depth=10,
    iterations=350, 
    learning_rate=0.1, 
    logging_level='Silent'
)
clf_rf_bitter = RandomForestClassifier(
    bootstrap=False,
    max_depth=100,
    max_features='auto',
    min_samples_leaf=1,
    min_samples_split=2,
    n_estimators=400
)

bitter_models_full = [
    {'model': clf_xgboost_bitter, 'name': 'XGBoost (No Feature Selection)'},
    {'model': clf_catboost_bitter, 'name': 'CatBoost (No Feature Selection)'},
    {'model': clf_rf_bitter, 'name': 'Random Forest (No Feature Selection)'},
]

# %% [markdown]
# Phyto-Dictionary

# %%
evaluate_all(bitter_models_full, X_train_bitter_scaled, y_train_bitter, X_test_bitter_scaled_pytho, y_test_bitter_pytho)
# Out:
# Model: XGBoost (No Feature Selection)
# Accuracy: 0.875
# Precision: 0.9074074074074074
# Average Precision: 0.9600489958949988
# AUROC: 0.9294765840220386
# Sensitivity 0.8909090909090909
# Specificity 0.8484848484848485
# F1-Score 0.8990825688073394
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84        33
#            1       0.91      0.89      0.90        55
#
#     accuracy                           0.88        88
#    macro avg       0.87      0.87      0.87        88
# weighted avg       0.88      0.88      0.88        88
#
# -----------------
#
# Model: CatBoost (No Feature Selection)
# Accuracy: 0.8863636363636364
# Precision: 0.9245283018867925
# Average Precision: 0.9644389389061261
# AUROC: 0.9349862258953168
# Sensitivity 0.8909090909090909
# Specificity 0.8787878787878788
# F1-Score 0.9074074074074073
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85        33
#            1       0.92      0.89      0.91        55
#
#     accuracy                           0.89        88
#    macro avg       0.88      0.88      0.88        88
# weighted avg       0.89      0.89      0.89        88
#
# -----------------
#
# Model: Random Forest (No Feature Selection)
# Accuracy: 0.8863636363636364
# Precision: 0.9245283018867925
# Average Precision: 0.9571506302899608
# AUROC: 0.9292011019283748
# Sensitivity 0.8909090909090909
# Specificity 0.8787878787878788
# F1-Score 0.9074074074074073
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85        33
#            1       0.92      0.89      0.91        55
#
#     accuracy                           0.89        88
#    macro avg       0.88      0.88      0.88        88
# weighted avg       0.89      0.89      0.89        88
#
# -----------------

# %% [markdown]
# Bitter-New

# %%
evaluate_all(bitter_models_full, X_train_bitter_scaled, y_train_bitter, X_test_bitter_scaled_bitternew, y_test_bitter_bitternew)
# Out:
# Model: XGBoost (No Feature Selection)
# Accuracy: 0.5925925925925926
# Precision: 1.0
# Average Precision: 1.0
# AUROC: N/A (Only 1 class in y_true)
# Sensitivity 0.5925925925925926
# Specificity 0.0
# F1-Score 0.7441860465116279
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.59      0.74        27
#
#     accuracy                           0.59        27
#    macro avg       0.50      0.30      0.37        27
# weighted avg       1.00      0.59      0.74        27
#
# -----------------
#
# Model: CatBoost (No Feature Selection)
# Accuracy: 0.5925925925925926
# Precision: 1.0
# Average Precision: 1.0
# AUROC: N/A (Only 1 class in y_true)
# Sensitivity 0.5925925925925926
# Specificity 0.0
# F1-Score 0.7441860465116279
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.59      0.74        27
#
#     accuracy                           0.59        27
#    macro avg       0.50      0.30      0.37        27
# weighted avg       1.00      0.59      0.74        27
#
# -----------------
#
# Model: Random Forest (No Feature Selection)
# Accuracy: 0.5925925925925926
# Precision: 1.0
# Average Precision: 1.0
# AUROC: N/A (Only 1 class in y_true)
# Sensitivity 0.5925925925925926
# Specificity 0.0
# F1-Score 0.7441860465116279
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.59      0.74        27
#
#     accuracy                           0.59        27
#    macro avg       0.50      0.30      0.37        27
# weighted avg       1.00      0.59      0.74        27
#
# -----------------

# %% [markdown]
# UNIMI

# %%
evaluate_all(bitter_models_full, X_train_bitter_scaled, y_train_bitter, X_test_bitter_scaled_unimi, y_test_bitter_unimi)
# Out:
# Model: XGBoost (No Feature Selection)
# Accuracy: 0.8392857142857143
# Precision: 0.8181818181818182
# Average Precision: 0.8629804203273626
# AUROC: 0.8893280632411067
# Sensitivity 0.782608695652174
# Specificity 0.8787878787878788
# F1-Score 0.8
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87        33
#            1       0.82      0.78      0.80        23
#
#     accuracy                           0.84        56
#    macro avg       0.84      0.83      0.83        56
# weighted avg       0.84      0.84      0.84        56
#
# -----------------
#
# Model: CatBoost (No Feature Selection)
# Accuracy: 0.6964285714285714
# Precision: 0.625
# Average Precision: 0.8006447136837629
# AUROC: 0.8405797101449275
# Sensitivity 0.6521739130434783
# Specificity 0.7272727272727273
# F1-Score 0.6382978723404256
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.75      0.73      0.74        33
#            1       0.62      0.65      0.64        23
#
#     accuracy                           0.70        56
#    macro avg       0.69      0.69      0.69        56
# weighted avg       0.70      0.70      0.70        56
#
# -----------------
#
# Model: Random Forest (No Feature Selection)
# Accuracy: 0.6607142857142857
# Precision: 0.6
# Average Precision: 0.738177765024629
# AUROC: 0.8069828722002635
# Sensitivity 0.5217391304347826
# Specificity 0.7575757575757576
# F1-Score 0.5581395348837209
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.69      0.76      0.72        33
#            1       0.60      0.52      0.56        23
#
#     accuracy                           0.66        56
#    macro avg       0.65      0.64      0.64        56
# weighted avg       0.66      0.66      0.66        56
#
# -----------------

# %% [markdown]
# # Sweet Classifier (Boruta Shap)

# %%
from BorutaShap import BorutaShap

# %%
clf_xgboost_sweet_ba = XGBClassifier(
    colsample_bytree=0.3,
    learning_rate=0.01,
    max_depth=10,
    n_estimators=1000
)
clf_catboost_sweet_ba = CatBoostClassifier(
    depth=6,
    iterations=250, 
    learning_rate=0.2, 
    logging_level='Silent'
)
clf_rf_sweet_ba = RandomForestClassifier(
    bootstrap=False,
    max_depth=None,
    max_features='auto',
    min_samples_leaf=1,
    min_samples_split=10,
    n_estimators=400
)
sweet_models_full = [
    {'model': clf_xgboost_sweet_ba, 'name': 'XGBoost (BorutaShap)'},
    {'model': clf_catboost_sweet_ba, 'name': 'CatBoost (BorutaShap)'},
    {'model': clf_rf_sweet_ba, 'name': 'Random Forest (BorutaShap)'},
]

# %%
clf_xgboost_bitter_ba = XGBClassifier(
    colsample_bytree=0.3,
    learning_rate=0.01,
    max_depth=10,
    n_estimators=500
)
clf_catboost_bitter_ba = CatBoostClassifier(
    depth=10,
    iterations=350, 
    learning_rate=0.1, 
    logging_level='Silent'
)
clf_rf_bitter_ba = RandomForestClassifier(
    bootstrap=False,
    max_depth=100,
    max_features='auto',
    min_samples_leaf=1,
    min_samples_split=2,
    n_estimators=400
)

bitter_models_full = [
    {'model': clf_xgboost_bitter_ba, 'name': 'XGBoost (BorutaShap)'},
    {'model': clf_catboost_bitter_ba, 'name': 'CatBoost (BorutaShap)'},
    {'model': clf_rf_bitter_ba, 'name': 'Random Forest (BorutaShap)'},
]

# %%
sweet_selector = BorutaShap(importance_measure='shap', classification=True)

# %%
sweet_selector.fit(
    X=X_train_sweet_scaled, y=y_train_sweet['Target'],
    n_trials=500,
    sample=False,
    verbose=True,
    random_state=42
)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# 275 attributes confirmed important: ['Mor17p', 'CATS2D_07_DL', 'F03C-N', 'SM13_EA(bo)', 'Chi_D/Dt', 'SpMin3_Bh(v)', 'LOC', 'SM5_B(p)', 'SpMax_B(v)', 'SpMax_AEA(bo)', 'Mor14v', 'SpMax_B(m)', 'SM11_EA(bo)', 'TDB01i', 'MATS4e', 'Hy', 'MWC05', 'GATS4e', 'CATS2D_05_DN', 'ATSC4i', 'SpPosA_G/D', 'H4s', 'Eig01_AEA(ed)', 'Eig04_AEA(ed)', 'SM5_H2', 'TDB05s', 'MWC06', 'RDF010s', 'J_Dt', 'SM5_B(v)', 'SM08_EA(bo)', 'SM4_B(v)', 'ATS3v', 'Eig01_AEA(ri)', 'R5s+', 'SpDiam_H2', 'CATS2D_07_AL', 'Eig01_AEA(dm)', 'SM11_EA(ed)', 'SM6_H2', 'Eig01_EA(ed)', 'P_VSA_LogP_5', 'HATS6v', 'MATS6p', 'SpMAD_B(i)', 'SM14_EA(ri)', 'piPC07', 'SM6_B(s)', 'RBF', 'SpMaxA_D/Dt', 'Mor14p', 'CATS3D_03_DL', 'SpDiam_AEA(ed)', 'SpMax_B(p)', 'ATSC2e', 'SpAD_Dz(m)', 'MATS2e', 'AVS_B(i)', 'RDF020m', 'SpMax_B(s)', 'ATSC4s', 'SM08_AEA(bo)', 'SM15_EA(ed)', 'RDF020u', 'CATS2D_09_AL', 'SM6_L', 'ATSC5i', 'J_G', 'SM06_EA(bo)', 'SM6_B(p)', 'SpDiam_EA(ri)', 'ATS3s', 'F03C-O', 'AVS_B(v)', 'VR2_B(p)', 'B01C-N', 'ATS6s', 'Eig03_EA(bo)', 'VE1_B(s)', 'CATS2D_03_PL', 'MATS6m', 'CATS2D_04_PN', 'SpMax1_Bh(m)', 'Eig06_EA(ed)', 'RDF085i', 'nN', 'rGes', 'SpMax1_Bh(s)', 'SpMax_EA(ri)', 'H_Dz(p)', 'Mor29p', 'B03C-N', 'SpMax_L', 'F02C-O', 'SM6_B(i)', 'totalcharge', 'SpDiam_B(s)', 'B03C-O', 'VR2_B(i)', 'N%', 'RDF030s', 'EE_B(s)', 'R4s+', 'ATSC5v', 'piPC04', 'B01C-O', 'SIC4', 'MATS4s', 'Mor16v', 'ATSC3v', 'GATS6v', 'SpMax1_Bh(e)', 'SpDiam_B(v)', 'AMW', 'SpMax1_Bh(v)', 'SM02_EA(bo)', 'P_VSA_ppp_ter', 'piPC10', 'TDB03p', 'R1u+', 'SM14_EA(bo)', 'SM13_EA(ri)', 'GATS2p', 'Eta_beta_A', 'SpMaxA_EA(ed)', 'piPC05', 'SpMin7_Bh(s)', 'TDB02i', 'Eig06_AEA(ed)', 'SpMax_B(i)', 'X3', 'C-041', 'Eig08_EA(ri)', 'SpMax_EA(bo)', 'piPC09', 'TDB04e', 'SM13_AEA(ri)', 'SpMax_AEA(ri)', 'CATS2D_08_DL', 'Mor20v', 'O%', 'piPC02', 'P_VSA_i_4', 'F02C-N', 'SpDiam_B(e)', 'piPC03', 'P_VSA_e_5', 'SM15_EA(ri)', 'B02C-N', 'CATS3D_06_AL', 'H5u', 'SpMax_B(e)', 'Eig02_EA(bo)', 'Eig01_EA(bo)', 'Mor28m', 'SpMax_EA(ed)', 'ChiA_B(p)', 'ATSC2s', 'AVS_B(p)', 'VR2_B(v)', 'SM15_EA(bo)', 'SRW08', 'J_D/Dt', 'GATS2e', 'MATS6v', 'SM6_B(v)', 'Mor16p', 'SpDiam_B(p)', 'BIC3', 'R1e+', 'SM10_AEA(dm)', 'SM05_EA(bo)', 'P_VSA_e_3', 'SM12_EA(ed)', 'BIC4', 'MAXDP', 'P_VSA_MR_1', 'SpMax1_Bh(p)', 'MATS2p', 'MLOGP', 'TDB04s', 'IC5', 'SpDiam_EA(ed)', 'Eig01_EA(ri)', 'RDF020p', 'SM14_EA(ed)', 'VE1_RG', 'RTi+', 'Mor12v', 'F01C-N', 'Mor25s', 'GATS6m', 'RDF020v', 'SpMax3_Bh(v)', 'Eig04_AEA(bo)', 'piID', 'SpMAD_G/D', 'CATS3D_02_AL', 'RDF040s', 'VR2_B(e)', 'SM11_AEA(ri)', 'F01C-O', 'SM03_AEA(ri)', 'SpMax_Dz(e)', 'AVS_B(m)', 'P_VSA_m_3', 'ChiA_B(i)', 'Mor14m', 'SpMin3_Bh(e)', 'SpMAD_B(e)', 'SM06_AEA(bo)', 'Mor19v', 'SM04_EA(bo)', 'CATS2D_04_PL', 'Eig06_EA(ri)', 'H_Dz(i)', 'CATS3D_02_DL', 'SM13_EA(ed)', 'TDB05e', 'SM10_EA(bo)', 'SRW10', 'Eig07_EA(ri)', 'CATS2D_03_DL', 'R3s+', 'SpMax1_Bh(i)', 'GGI8', 'SM12_AEA(ri)', 'SpMax3_Bh(i)', 'Eig01_AEA(bo)', 'SpMin1_Bh(e)', 'Mor29v', 'GATS4s', 'Mor16m', 'Mor20p', 'SM07_EA(bo)', 'TDB03u', 'VE1sign_RG', 'SM07_AEA(bo)', 'WiA_B(e)', 'SM5_B(s)', 'SpDiam_L', 'P_VSA_i_3', 'SIC3', 'ATSC3i', 'CATS3D_08_DL', 'SM12_EA(bo)', 'SpDiam_B(m)', 'F04C-C', 'SpMAD_B(v)', 'SpMax_AEA(ed)', 'H5i', 'ATS4v', 'SpMin3_Bh(i)', 'MAXDN', 'X3A', 'piPC08', 'P_VSA_LogP_2', 'SpMax_AEA(dm)', 'SpMAD_EA(bo)', 'Eig09_EA(ri)', 'piPC06', 'SM4_B(p)', 'Mor19p', 'P_VSA_ppp_cyc', 'MATS2i', 'SpDiam_EA(bo)', 'MLOGP2', 'SpDiam_B(i)', 'CATS2D_02_DL', 'Eig08_EA(ed)', 'SssO', 'SM09_EA(bo)', 'VR2_B(m)', 'ATS4s', 'R1i+']
# 4692 attributes confirmed unimportant: ['SpMaxA_EA', 'B06C-Br', 'R7s+', 'Mor11u', 'Eig05_AEA(dm)', 'CATS3D_04_PN', 'B06O-S', 'F10O-P', 'B06S-I', 'VE2sign_G/D', 'F03O-I', 'CATS2D_07_DD', 'C-014', 'Eig08_AEA(dm)', 'F09Br-I', 'F07X-X', 'CATS3D_00_PP', 'F03Br-Si', 'B08S-F', 'B04P-Si', 'J_B(s)', 'NsSeH', 'Chi1_AEA(ed)', 'Wi_Dt', 'RDF060v', 'Mor27i', 'EE_B(v)', 'B09F-F', 'DP06', 'B09O-F', 'F07Cl-B', 'Mor08v', 'nP(=O)O2R', 'B03Cl-X', 'SP11', 'SM2_D', 'G1i', 'CATS2D_04_NN', 'T(O..Br)', 'HATS2s', 'B01F-I', 'Mor12p', 'B02N-Si', 'SpMax_Dz(Z)', 'F03N-I', 'EE_D/Dt', 'P_VSA_ppp_P', 'CATS2D_06_DL', 'F02P-Cl', 'CATS3D_17_AL', 'F09O-Cl', 'ATS4e', 'B09S-S', 'B10P-Br', 'GGI3', 'CATS3D_19_PL', 'CATS3D_04_DD', 'B07C-S', 'B03Br-X', 'RTe', 'F02Si-X', 'HATS8e', 'R3e', 'CATS3D_14_DN', 'F07S-B', 'F01C-Br', 'B07S-Si', 'F04Cl-B', 'ATS2s', 'P1s', 'B03C-B', 'B04Br-B', 'B06F-Cl', 'SM1_B(m)', 'Chi0_AEA(bo)', 'Br-091', 'S-109', 'B09N-I', 'P-119', 'F08O-P', 'F08C-I', 'SdSe', 'GATS6e', 'RDF070i', 'F08P-X', 'B10Si-X', 'B04F-F', 'SsNH3+', 'StsC', 'Br-095', 'F08I-B', 'CATS3D_02_PP', 'F04C-F', 'GATS4i', 'H_Dz(Z)', 'HNar', 'Eig05_AEA(ri)', 'SsssssAs', 'SpMax_D', 'Chi_Dz(v)', 'L3p', 'B01N-Si', 'B10B-Si', 'Mor04p', 'B07Br-Si', 'SpPosLog_B(s)', 'CATS2D_05_AL', 'CATS3D_11_DD', 'nSO4', 'Mor21i', 'nArCONH2', 'TDB01r', 'B06P-I', 'Mp', 'B09O-P', 'B02C-B', 'SM5_B(e)', 'Eig14_EA(bo)', 'Eig03_EA(ed)', 'B01S-I', 'PHI', 'nR11', 'F01F-B', 'B10S-Cl', 'RDF155m', 'nHAcc', 'TDB07p', 'G(P..Br)', 'Ges', 'B07C-N', 'F07Br-I', 'H3v', 'B09C-P', 'RDF100e', 'NddssSe', 'R5i', 'B05P-P', 'Mor22e', 'B08C-N', 'MATS6s', 'Mor05v', 'Eig02_EA(dm)', 'SpAD_B(v)', 'B07F-Br', 'F03C-S', 'F08Cl-Br', 'nHM', 'Eig03_AEA(ed)', 'CATS3D_01_AN', 'G(O..F)', 'F08Cl-X', 'Mor29m', 'CATS2D_06_PL', 'B09Cl-Cl', 'B09P-B', 'nR10', 'R5i+', 'P-117', 'CATS2D_01_AP', 'Mor30i', 'WiA_Dz(e)', 'Ho_G/D', 'F05F-I', 'nR#C-', 'SpDiam_Dz(m)', 'SpAbs_Dz(e)', 'Mor10m', 'H0u', 'Eig09_EA', 'CATS2D_07_PP', 'RDF060e', 'NsF', 'B06O-Cl', 'SM14_EA(dm)', 'nCconj', 'SpMin2_Bh(v)', 'B02I-B', 'B10F-X', 'SM07_EA(dm)', 'F06Cl-Br', 'D/Dtr12', 'CATS3D_09_AL', 'SpMAD_AEA(dm)', 'R1p', 'F07C-Br', 'F08Si-Si', 'T(N..F)', 'HATS1e', 'C-042', 'B06F-F', 'RDF100i', 'G(F..F)', 'B03Si-Si', 'CATS2D_02_PN', 'B09C-Br', 'Mor01i', 'X1', 'NsssCH', 'NssSnH2', 'RDF120e', 'ATSC4v', 'CATS3D_09_AP', 'B09F-B', 'nArNR2', 'Mor15v', 'F02S-S', 'F08N-Br', 'X0v', 'F09Cl-Br', 'BIC2', 'E1s', 'nHBonds', 'H1m', 'Mor16s', 'ATS5m', 'B01S-S', 'B04P-I', 'F02S-P', 'MWC09', 'SpPosA_H2', 'Ho_Dt', 'SM15_AEA(dm)', 'B02F-Cl', 'B04F-B', 'B07B-Si', 'B10X-X', 'Eig10_AEA(ed)', 'B03N-Br', 'SM05_EA(ri)', 'B06P-P', 'Mor01u', 'Mor03u', 'B04S-Br', 'CATS3D_16_NL', 'HIC', 'CATS2D_02_AP', 'SM08_EA(ri)', 'F01P-Si', 'SM07_AEA(ri)', 'CATS3D_14_DA', 'CATS3D_18_DL', 'F01S-B', 'B09N-Cl', 'Br-103', 'Mor32m', 'RDF055i', 'HATS0u', 'I-099', 'RDF145s', 'HATS4p', 'nPyrroles', 'CATS3D_01_DL', 'Eig13_AEA(dm)', 'nC', 'F06Br-X', 'B04S-B', 'TDB03i', 'Mor13i', 'F06N-Si', 'Eig11_AEA(dm)', 'F02N-Si', 'Mor07u', 'Chi_B(p)', 'B04I-I', 'F10Cl-Cl', 'Wi_Dz(m)', 'B03N-N', 'L3e', 'Wi_Dz(Z)', 'F01Cl-I', 'F02B-B', 'VE1sign_B(m)', 'SpPos_H2', 'RDF065e', 'SP14', 'RDF135u', 'B03Si-X', 'RDF115u', 'B10S-S', 'RDF075v', 'SpAD_Dz(i)', 'Eig05_EA(ri)', 'NsssP', 'B07N-I', 'X5sol', 'QYYm', 'RDF035p', 'SM03_AEA(bo)', 'ATS3i', 'Eig06_EA(dm)', 'T(F..Br)', 'Mor17s', 'RTi', 'HATS8i', 'NsLi', 'E2p', 'CATS3D_17_DP', 'F09P-B', 'Tm', 'NssBe', 'TDB07e', 'VvdwMG', 'SM5_Dt', 'B06Cl-X', 'RDF050m', 'SpMin4_Bh(e)', 'B06Cl-Br', 'B05F-B', 'P1p', 'nBeta-Lactams', 'Chi_Dz(Z)', 'VE2_L', 'F01N-N', 'G(F..Br)', 'SpMin8_Bh(m)', 'F03S-X', 'RDF115m', 'CATS2D_04_AA', 'SM3_Dz(Z)', 'Se', 'Eig15_AEA(ed)', 'AVS_Dz(i)', 'Mor32i', 'Mor04e', 'nArCN', 'Psi_e_A', 'SpPosLog_Dz(v)', 'HDcpx', 'B01N-O', 'R6i+', 'SIC0', 'CATS3D_16_AA', 'HATS3v', 'RDF075p', 'SM04_EA', 'nOxolanes', 'CIC1', 'CATS3D_10_DD', 'B03I-X', 'Mor27s', 'G(Br..I)', 'Chi0_EA(ed)', 'F03F-I', 'Eta_C_A', 'H8p', 'VE2_RG', 'B01Br-Si', 'CATS3D_06_DA', 'CATS3D_12_AN', 'F07Cl-Br', 'B08Si-X', 'CATS3D_01_AP', 'B06N-I', 'QXXs', ' ...
# 122 tentative attributes remains: ['SM3_H2', 'SM4_H2', 'SM12_AEA(ed)', 'Eig07_EA(bo)', 'F04C-O', 'SpAD_AEA(ed)', 'HATS7e', 'Mi', 'Chi0_EA(dm)', 'SpPosLog_Dz(m)', 'RDF030m', 'SpPosA_B(i)', 'Mor20i', 'SpMin3_Bh(p)', 'MATS2v', 'ATSC6i', 'BLI', 'SM5_B(i)', 'Pol', 'F03C-C', 'Mor20e', 'R5s', 'Mor25v', 'TDB04u', 'Mv', 'P_VSA_MR_5', 'NssO', 'F02C-C', 'ATSC1v', 'ATS4m', 'B02O-O', 'H_Dz(e)', 'Mor05p', 'AVS_H2', 'CIC4', 'GNar', 'ATSC2i', 'Psi_e_0', 'EE_B(p)', 'CATS3D_04_DL', 'SM1_B(e)', 'HATS7i', 'EE_L', 'SM04_AEA(bo)', 'RDF040u', 'Mor27v', 'Mor14u', 'P_VSA_m_2', 'SpMAD_B(p)', 'VE3_B(i)', 'SpDiam_AEA(bo)', 'SM4_B(s)', 'RDF040i', 'SpMin1_Bh(p)', 'AVS_B(e)', 'Mor14e', 'ChiA_B(v)', 'VR2_B(s)', 'SpMax4_Bh(m)', 'SM6_B(e)', 'SpMAD_D/Dt', 'C%', 'MPC03', 'CATS2D_00_DP', 'GATS2v', 'MATS3m', 'MPC06', 'SpMin2_Bh(i)', 'HATS2m', 'Eig04_EA(ri)', 'GATS1v', 'Eig04_EA', 'SpMax4_Bh(v)', 'RDF090i', 'SpMAD_B(m)', 'SM03_AEA(ed)', 'Eig09_AEA(bo)', 'WiA_D/Dt', 'DISPp', 'SM02_AEA(ed)', 'SM5_L', 'SM09_EA(ed)', 'SRW06', 'Eig08_AEA(bo)', 'EE_H2', 'SM12_EA(ri)', 'SM10_EA(ri)', 'GATS1e', 'TDB02p', 'R3m+', 'MCD', 'P_VSA_p_2', 'Mor18i', 'SM10_EA(ed)', 'SM3_B(p)', 'SpMax4_Bh(e)', 'Mor27p', 'J_G/D', 'GATS1p', 'ATSC5p', 'SpMax_H2', 'SM6_B(m)', 'X1Av', 'MPC05', 'SM11_EA(ri)', 'SM1_Dz(i)', 'CATS3D_04_PL', 'SM12_AEA(bo)', 'MATS6i', 'ATS3p', 'SpPosA_L', 'Eig11_AEA(ed)', 'BIC5', 'ATS4p', 'F02O-O', 'MWC07', 'SM02_AEA(dm)', 'CATS3D_00_DP', 'SM02_EA(ed)', 'ISH', 'Eig07_AEA(bo)', 'WiA_B(p)']

# %%
X_sweet_subset = sweet_selector.Subset()
X_sweet_subset_cols = X_sweet_subset.columns



X_train_sweet_subset = X_train_sweet_scaled[X_sweet_subset_cols]
X_test_sweet_subset = X_test_sweet_scaled[X_sweet_subset_cols]

# %%
X_sweet_borutashap = pd.DataFrame(X_sweet_subset_cols)
X_sweet_borutashap.to_csv("X_sweet_borutashap.csv")

# %%
evaluate_all(sweet_models_full, X_train_sweet_subset, y_train_sweet, X_test_sweet_subset, y_test_sweet)
# Out:
# Model: XGBoost (BorutaShap)
# Accuracy: 0.7987012987012987
# Precision: 0.9111111111111111
# Average Precision: 0.9540230290360356
# AUROC: 0.8942662779397473
# Sensitivity 0.780952380952381
# Specificity 0.8367346938775511
# F1-Score 0.841025641025641
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.64      0.84      0.73        49
#            1       0.91      0.78      0.84       105
#
#     accuracy                           0.80       154
#    macro avg       0.78      0.81      0.78       154
# weighted avg       0.83      0.80      0.80       154
#
# -----------------
#
# Model: CatBoost (BorutaShap)
# Accuracy: 0.7727272727272727
# Precision: 0.8804347826086957
# Average Precision: 0.949677001167498
# AUROC: 0.8841593780369291
# Sensitivity 0.7714285714285715
# Specificity 0.7755102040816326
# F1-Score 0.8223350253807107
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.61      0.78      0.68        49
#            1       0.88      0.77      0.82       105
#
#     accuracy                           0.77       154
#    macro avg       0.75      0.77      0.75       154
# weighted avg       0.80      0.77      0.78       154
#
# -----------------
#
# Model: Random Forest (BorutaShap)
# Accuracy: 0.7922077922077922
# Precision: 0.9101123595505618
# Average Precision: 0.9524958431597254
# AUROC: 0.8899902818270166
# Sensitivity 0.7714285714285715
# Specificity 0.8367346938775511
# F1-Score 0.8350515463917525
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.63      0.84      0.72        49
#            1       0.91      0.77      0.84       105
#
#     accuracy                           0.79       154
#    macro avg       0.77      0.80      0.78       154
# weighted avg       0.82      0.79      0.80       154
#
# -----------------

# %% [markdown]
# # Bitter Classifier (Boruta Shap)

# %%
bitter_selector = BorutaShap(importance_measure='shap', classification=True)

# %%
bitter_selector.fit(
    X=X_train_bitter_scaled,
    y=y_train_bitter['Target'],
    n_trials=500,
    sample=False,
    verbose=True,
    random_state=42
)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# 270 attributes confirmed important: ['Eig08_EA(ri)', 'GATS5m', 'SPAM', 'Mv', 'R5p', 'Mor16p', 'ATSC4s', 'P_VSA_ppp_cyc', 'PCD', 'ATSC5v', 'O%', 'SpMax3_Bh(e)', 'EE_B(i)', 'R6m', 'RDF020s', 'AVS_B(i)', 'P_VSA_e_3', 'H0m', 'SsssCH', 'MATS2i', 'SpMAD_EA(bo)', 'Mor15m', 'nO', 'GATS6e', 'RDF040i', 'SpMax1_Bh(m)', 'SpMax3_Bh(v)', 'SM11_AEA(ri)', 'CATS3D_02_AA', 'piPC10', 'SM08_AEA(bo)', 'B03C-N', 'Mor12e', 'ATS4p', 'SpMin1_Bh(p)', 'CATS2D_08_AL', 'SM13_EA(ed)', 'SpMax_EA', 'F01C-O', 'VE3_RG', 'GATS2p', 'P_VSA_ppp_ter', 'TDB04u', 'ATSC5i', 'R5s+', 'CATS2D_09_AL', 'SpMax_EA(ed)', 'WiA_D/Dt', 'ATSC1m', 'SM15_EA(ed)', 'R6v', 'RDF020p', 'R3s+', 'HATS6m', 'Mor03i', 'SpDiam_B(p)', 'GATS6m', 'MAXDN', 'CATS2D_04_AA', 'GATS1p', 'SpMax1_Bh(e)', 'B01C-N', 'SpMax_AEA(ri)', 'SpMax_AEA(ed)', 'ATS5p', 'MATS4e', 'H_Dz(p)', 'Eig06_AEA(bo)', 'SM08_EA(ed)', 'HATS6v', 'TDB03p', 'SpDiam_B(v)', 'ATSC5p', 'SpDiam_B(e)', 'SpMax_L', 'ATSC4p', 'SM5_RG', 'P_VSA_MR_6', 'P_VSA_ppp_A', 'ATSC3v', 'P_VSA_m_3', 'ATSC3p', 'Mi', 'RDF020m', 'F02C-N', 'ATS3p', 'ATSC4v', 'CATS3D_07_DL', 'GATS4e', 'SpDiam_H2', 'F01C-N', 'nN', 'MAXDP', 'SM4_B(i)', 'CATS3D_09_DL', 'RTp', 'SpDiam_B(i)', 'Eig01_EA(ed)', 'CATS3D_08_DL', 'Mor14e', 'RDF060s', 'Eta_betaP_A', 'P_VSA_i_4', 'TDB02p', 'ATSC2s', 'SM6_B(i)', 'totalcharge', 'SM6_B(s)', 'AVS_B(v)', 'CATS3D_06_DL', 'Eig08_AEA(ri)', 'SM5_B(i)', 'CATS3D_04_PL', 'F02C-O', 'SpMAD_B(m)', 'CATS3D_03_DL', 'SM5_B(s)', 'AVS_B(m)', 'SpMax_B(p)', 'J_Dt', 'Mp', 'SM10_EA(ed)', 'H4s', 'GATS2e', 'SM3_B(s)', 'SpMax3_Bh(i)', 'R2i', 'R2e', 'Eta_beta_A', 'MATS6m', 'R6i', 'P_VSA_e_5', 'Eig01_AEA(ed)', 'QXXs', 'SpDiam_AEA(bo)', 'RDF040p', 'SM6_RG', 'MATS5m', 'SpMAD_B(e)', 'GATS5s', 'SpMAD_B(p)', 'SM03_AEA(bo)', 'TDB02i', 'ATS6s', 'HATS6p', 'SM4_B(s)', 'SpMAD_G/D', 'SpDiam_L', 'ATSC4i', 'TDB05e', 'SM12_EA(ed)', 'MATS4s', 'SpDiam_EA(ed)', 'MLOGP', 'GATS6s', 'SpPosA_B(i)', 'Eig06_EA(ed)', 'SpMax_B(m)', 'SM07_AEA(bo)', 'SM04_AEA(bo)', 'GATS4s', 'F03C-O', 'SpMax_B(v)', 'CATS3D_02_DL', 'R6s', 'CATS2D_09_DL', 'Eig06_EA(ri)', 'TDB05s', 'PCR', 'GATS1m', 'CATS2D_00_DP', 'RDF040e', 'SpPosA_B(p)', 'DLS_cons', 'SpDiam_B(s)', 'SM05_AEA(bo)', 'Mor14u', 'Mor14i', 'F04C-C', 'DISPp', 'CATS2D_07_DL', 'SpDiam_RG', 'H0p', 'SpMin1_Bh(e)', 'Eig01_AEA(ri)', 'Mor25s', 'SM02_AEA(dm)', 'ATSC1i', 'Mor16v', 'G(O..O)', 'SpMAD_B(i)', 'SpMax_B(s)', 'ZM2MulPer', 'ATSC6p', 'SpDiam_A', 'B02C-N', 'N%', 'Eig06_AEA(ri)', 'Mor03e', 'Eig01_AEA(bo)', 'ATSC2i', 'SM1_Dz(i)', 'rGes', 'S3K', 'SM12_AEA(ed)', 'SpMax_EA(bo)', 'T(O..O)', 'SM10_EA(bo)', 'SM14_EA(ed)', 'Eig06_EA(bo)', 'EE_B(s)', 'GATS4m', 'RDF020v', 'TDB01i', 'SpMAD_B(v)', 'SM13_AEA(ed)', 'SpMax1_Bh(s)', 'SpDiam_AEA(ed)', 'MATS6v', 'ATSC3m', 'RDF010s', 'SpMax1_Bh(i)', 'RDF030m', 'Chi1_EA(dm)', 'SM6_L', 'AVS_B(p)', 'E3p', 'CATS2D_04_PL', 'Mor16m', 'SpMax_AEA(bo)', 'R4s+', 'SpMAD_B(s)', 'ATSC3i', 'SpDiam_AEA(ri)', 'ZM2V', 'CATS2D_08_DL', 'F03C-N', 'GATS2m', 'SpDiam_B(m)', 'R5v', 'SpPosA_G/D', 'SpMax_H2', 'L2m', 'Eig01_EA', 'TDB04e', 'SpMax_B(e)', 'HATS5p', 'SpDiam_EA(bo)', 'P_VSA_i_3', 'SM06_AEA(bo)', 'SM14_AEA(ed)', 'RDF040u', 'SM09_EA(ed)', 'SM6_B(e)', 'CATS2D_02_DL', 'R6e', 'Chi_D/Dt', 'MLOGP2', 'R6p', 'ATSC6i', 'PW5', 'RDF035p', 'VE1_RG', 'SM10_AEA(dm)', 'SM5_B(e)', 'TDB04s', 'SpMax_B(i)', 'QXXm', 'CATS3D_00_DP', 'SpDiam_EA(ri)']
# 4688 attributes confirmed unimportant: ['B06P-F', 'CATS3D_11_DL', 'Eig04_AEA(bo)', 'Eig03_EA(dm)', 'F07F-Cl', 'SpAbs_Dz(Z)', 'C-013', 'S-106', 'RDF125p', 'SpMax5_Bh(i)', 'F03N-N', 'F01P-B', 'Mor23m', 'F08S-Br', 'SpMax2_Bh(i)', 'F09O-Br', 'VE2_G/D', 'B05N-F', 'F04N-O', 'B04N-P', 'ZM2Per', 'Mor31e', 'P-120', 'TDB01e', 'ICR', 'F09P-Cl', 'SddsAs', 'SpAbs_Dz(i)', 'B03S-B', 'Mor17e', 'SpPos_RG', 'TDB04p', 'CATS2D_08_PN', 'SpMin5_Bh(m)', 'T(O..I)', 'CATS3D_07_PN', 'BBI', 'SM2_Dz(Z)', 'F10P-Si', 'SpAD_H2', 'SIC2', 'F05Cl-B', 'SM6_X', 'CATS3D_14_PN', 'SpPosLog_B(m)', 'SpAbs_G/D', 'F10C-I', 'D/Dtr11', 'Mor23i', 'Mor04v', 'SpMaxA_EA(bo)', 'Mor04u', 'RDF010p', 'MWC08', 'NssCH2', 'GATS5p', 'F08S-F', 'B09S-B', 'SpPos_D', 'SM12_AEA(bo)', 'MPC03', 'SpMin1_Bh(i)', 'SaasC', 'MWC05', 'CATS2D_04_DP', 'SpMAD_EA(ri)', 'RDF015i', 'Eig09_AEA(ri)', 'E3e', 'PW3', 'SM2_B(s)', 'B01F-Si', 'CATS2D_07_DP', 'ATSC5m', 'nCHRX2', 'Mor05i', 'B10O-Cl', 'F09S-S', 'F09S-B', 'SssSiH2', 'ATS1e', 'CATS2D_00_PP', 'F06S-I', 'F01O-Si', 'RDF120m', 'TDB01m', 'P_VSA_ppp_L', 'F04O-F', 'X4Av', 'RDF070v', 'F09O-I', 'VR2_L', 'CATS2D_01_PN', 'B03O-F', 'B07F-X', 'Mor16s', 'nR04', 'R1v+', 'nOHt', 'GATS5e', 'B01X-X', 'B05S-Si', 'B07C-S', 'B07F-B', 'L2u', 'L1i', 'F09B-X', 'MPC10', 'TDB06p', 'Eig03_AEA(dm)', 'B07F-Si', 'B08O-S', 'G(S..P)', 'CATS3D_09_NN', 'GGI3', 'G2i', 'B08N-Br', 'B10C-I', 'X1v', 'B08O-Si', 'R2i+', 'E3u', 'B06N-X', 'NssBH', 'R4m', 'R1i+', 'B04O-B', 'SpMaxA_Dt', 'B02N-B', 'B09C-O', 'P_VSA_p_4', 'R8u+', 'SM14_AEA(ri)', 'NdsssAs', 'MATS1i', 'B05S-Br', 'TPC', 'SM05_AEA(ri)', 'G(S..Cl)', 'VE3sign_L', 'WiA_Dz(p)', 'SM08_AEA(dm)', 'B09Cl-Br', 'IDM', 'F08O-O', 'Mor06p', 'SpPos_Dz(e)', 'I-099', 'H8u', 'C-017', 'P_VSA_MR_4', 'SpMin3_Bh(p)', 'Wi_H2', 'R3u+', 'JGI7', 'SpPos_B(s)', 'nCsp', 'VR3_B(p)', 'nRCOOH', 'VE1_B(m)', 'B09O-Si', 'SpPos_D/Dt', 'B10O-F', 'B06B-X', 'Mor06v', 'SdssC', 'SpMaxA_AEA(ri)', 'VR3_L', 'B04Cl-X', 'F08N-B', 'B03C-S', 'VE1_B(v)', 'B07I-B', 'AAC', 'B04N-S', 'CATS3D_07_DD', 'Eig01_EA(dm)', 'F07Cl-I', 'B02C-O', 'SpMAD_Dz(m)', 'DISPv', 'SpMin6_Bh(i)', 'J_B(v)', 'B10S-S', 'SpMAD_Dt', 'CATS3D_03_PN', 'SpPosLog_Dz(m)', 'CATS3D_17_AP', 'P_VSA_e_4', 'GGI1', 'Chi_Dz(v)', 'CATS2D_02_NN', 'G3u', 'SM11_AEA(bo)', 'SpAD_G/D', 'F09S-I', 'F04P-I', 'H-053', 'B03Cl-B', 'B08C-N', 'SssssPb', 'B06O-Cl', 'B06Cl-Cl', 'nSH', 'SM4_Dz(i)', 'NsAsH2', 'CATS2D_05_AA', 'Mor24m', 'F08O-S', 'T(Br..I)', 'F04O-I', 'B05S-X', 'F07Br-I', 'F10B-Si', 'RTe+', 'NsssB', 'F03Cl-I', 'SpMaxA_EA(dm)', 'H4u', 'F04I-I', 'RDF090s', 'Psi_e_0', 'F02O-F', 'SsCl', 'nArCONR2', 'F10O-Si', 'Eig15_EA(bo)', 'T(O..Cl)', 'RDF050v', 'B01C-F', 'L3p', 'Eig03_EA', 'F02C-B', 'CATS2D_09_DN', 'nB', 'Eta_L', 'F05P-X', 'R7m', 'MATS6s', 'R4i', 'B09O-S', 'SpPosA_Dz(Z)', 'R2v+', 'Mor31u', 'SpMax3_Bh(s)', 'F01F-Si', 'F05P-F', 'T(S..S)', 'SM03_EA(bo)', 'P_VSA_p_3', 'GMTIV', 'F01N-B', 'F02S-I', 'MWC09', 'T(S..P)', 'n135-Triazines', 'B01O-Si', 'CATS3D_13_DA', 'VR3_B(m)', 'F04Cl-Br', 'AVS_B(s)', 'SM10_EA', 'B06Cl-B', 'Mor16u', 'SpMax5_Bh(s)', 'F08B-B', 'B10C-P', 'X1sol', 'G(S..Br)', 'B10N-B', 'CATS3D_16_PN', 'HATS2i', 'Eig13_EA(bo)', 'SM03_AEA(ed)', 'Ae', 'RDF095v', 'Chi_H2', 'P_VSA_p_1', 'B08Cl-Br', 'SM09_EA', 'Mor20e', 'Xu', 'Mor05m', 'B05P-I', 'DP13', 'HATS7s', 'B07N-N', 'Mor09i', 'B05C-S', 'F07S-Br', 'F06C-F', 'F01O-B', 'R3e', 'B03Cl-Cl', 'B05F-I', 'Psi_i_s', 'AVS_H2', 'Du', 'CATS2D_01_DP', 'SMTIV', 'Ho_B(s)', 'F05S-F', 'SRW04', 'F04B-Si', 'F09Cl-Cl', 'F03Cl-X', 'HATS5s', 'SpMax4_Bh(e)', 'SpAbs_B(v)', 'CATS2D_03_AP', 'ZM2', 'SpDiam_Dz(m)', 'HATS6i', 'B01B-X', 'F08O-B', 'F03Cl-Br', 'HyWi_B(p)', 'TDB07i', 'R5m+', 'GATS1s', 'Xt', 'nR09', 'Eig14_EA', 'F08N-N', 'HATS4m', 'F04C-B', 'Wi_D', 'F08C-Cl', 'B10P-X', 'NdsN', 'AROM', 'B09O-B', 'F10S-Si', 'X0A', 'MPC02', 'GATS7i', 'nRSR', 'F09O-P', 'Wi_B(v)', 'SM05_EA(ri)', 'S0K', 'nPO4', 'ATS7p', 'SssSe', 'Eig03_AEA(ri)', 'Mor21i', 'HTs', 'B05O-Si', 'EE_L', 'Cl-087', 'F10Br-Si', 'B02S-B', 'P_VSA_ppp_D', 'Mor22s', 'SM6_G/D', 'SpMAD_AEA(ed)', 'H-047', 'CATS3D_12_DL', 'TDB10m', 'HTv', 'CATS2D_ ...
# 131 tentative attributes remains: ['GATS2s', 'J_D/Dt', 'RTi', 'Eig01_EA(bo)', 'Mor12p', 'MATS4m', 'Eig08_AEA(bo)', 'AVS_RG', 'ATSC2e', 'ATS4s', 'DELS', 'TDB03i', 'RDF035v', 'H_Dz(i)', 'F05C-N', 'SM4_RG', 'Mor01s', 'SpPosA_B(v)', 'RDF020i', 'HTp', 'R7e', 'P_VSA_MR_3', 'Mor11m', 'SpMax_EA(ri)', 'SM3_RG', 'L2v', 'ATSC2v', 'SpMax_RG', 'SpMax4_Bh(p)', 'RDF040s', 'Mor28v', 'SpMin4_Bh(p)', 'ChiA_RG', 'R6u', 'HATS7u', 'SM15_AEA(ed)', 'SM04_AEA(ed)', 'Mor12v', 'H0v', 'NssO', 'SpMin5_Bh(e)', 'SM15_EA', 'SM6_H2', 'SM4_B(e)', 'VE1sign_RG', 'Chi0_EA(dm)', 'SpDiam_EA', 'DISPi', 'C%', 'SM09_AEA(bo)', 'SM03_AEA(ri)', 'TDB03u', 'SM3_B(i)', 'GATS1v', 'nOHs', 'ATSC7i', 'ChiA_B(v)', 'P_VSA_m_2', 'Eig08_EA(ed)', 'SpMin4_Bh(e)', 'SM6_B(p)', 'ChiA_B(p)', 'SpMin4_Bh(i)', 'P_VSA_LogP_3', 'SM11_EA(ed)', 'SM15_EA(bo)', 'Mor19m', 'P_VSA_LogP_4', 'SpMaxA_D/Dt', 'SpMAD_RG', 'SM08_EA(bo)', 'H2v', 'Eig08_EA', 'R5i', 'R5u', 'SpMax4_Bh(v)', 'CATS2D_05_DN', 'SpMax3_Bh(p)', 'SM4_B(p)', 'ATSC6v', 'GATS2i', 'P_VSA_p_2', 'Mor04s', 'SpMin8_Bh(m)', 'SpMin4_Bh(v)', 'SM05_AEA(ed)', 'piPC06', 'SM5_B(v)', 'RDF040v', 'SM6_B(v)', 'SM3_B(m)', 'P_VSA_MR_2', 'LOC', 'SM07_EA(ed)', 'AVS_B(e)', 'Eig09_EA(ri)', 'RDF020u', 'SM14_EA(bo)', 'HATSp', 'SM12_EA(bo)', 'SpMax_AEA(dm)', 'TDB01v', 'Hy', 'R7u', 'SM15_AEA(ri)', 'Eig05_EA(bo)', 'SAacc', 'Mor14v', 'RDF020e', 'SpMin4_Bh(s)', 'RDF030i', 'Eig05_AEA(bo)', 'R7i', 'Wi_Dz(i)', 'B02O-O', 'SM02_AEA(bo)', 'GATS1e', 'Mor24i', 'MATS1s', 'ATSC3e', 'SssO', 'SpMax1_Bh(p)', 'L2s', 'piID', 'SpMax3_Bh(m)', 'Eig01_EA(ri)', 'ATSC1v', 'AMW', 'ATSC3s', 'ATS3i', 'CATS2D_03_DA']

# %%
X_bitter_subset = bitter_selector.Subset()

# %%
X_bitter_subset_cols = X_bitter_subset.columns

X_bitter_borutashap = pd.DataFrame(X_bitter_subset_cols)
X_bitter_borutashap.to_csv("X_bitter_borutashap500.csv")

X_train_bitter_subset = X_train_bitter_scaled[X_bitter_subset_cols]
X_test_bitter_phyto_subset = X_test_bitter_scaled_pytho[X_bitter_subset_cols]
X_test_bitter_bitternew_subset = X_test_bitter_scaled_bitternew[X_bitter_subset_cols]
X_test_bitter_unimi_subset = X_test_bitter_scaled_unimi[X_bitter_subset_cols]

# %% [markdown]
# Phyto-Dictionary

# %%
evaluate_all(bitter_models_full, X_train_bitter_subset, y_train_bitter, X_test_bitter_phyto_subset, y_test_bitter_pytho)
# Out:
# Model: XGBoost (BorutaShap)
# Accuracy: 0.8977272727272727
# Precision: 0.9423076923076923
# Average Precision: 0.9611983572363016
# AUROC: 0.9272727272727272
# Sensitivity 0.8909090909090909
# Specificity 0.9090909090909091
# F1-Score 0.9158878504672897
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87        33
#            1       0.94      0.89      0.92        55
#
#     accuracy                           0.90        88
#    macro avg       0.89      0.90      0.89        88
# weighted avg       0.90      0.90      0.90        88
#
# -----------------
#
# Model: CatBoost (BorutaShap)
# Accuracy: 0.8977272727272727
# Precision: 0.9259259259259259
# Average Precision: 0.969051752074148
# AUROC: 0.9393939393939394
# Sensitivity 0.9090909090909091
# Specificity 0.8787878787878788
# F1-Score 0.9174311926605504
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87        33
#            1       0.93      0.91      0.92        55
#
#     accuracy                           0.90        88
#    macro avg       0.89      0.89      0.89        88
# weighted avg       0.90      0.90      0.90        88
#
# -----------------
#
# Model: Random Forest (BorutaShap)
# Accuracy: 0.8977272727272727
# Precision: 0.9259259259259259
# Average Precision: 0.9607170844984986
# AUROC: 0.9333333333333333
# Sensitivity 0.9090909090909091
# Specificity 0.8787878787878788
# F1-Score 0.9174311926605504
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87        33
#            1       0.93      0.91      0.92        55
#
#     accuracy                           0.90        88
#    macro avg       0.89      0.89      0.89        88
# weighted avg       0.90      0.90      0.90        88
#
# -----------------

# %% [markdown]
# Bitter-New

# %%
evaluate_all(bitter_models_full, X_train_bitter_subset, y_train_bitter, X_test_bitter_bitternew_subset, y_test_bitter_bitternew)
# Out:
# Model: XGBoost (BorutaShap)
# Accuracy: 0.5185185185185185
# Precision: 1.0
# Average Precision: 1.0
# AUROC: N/A (Only 1 class in y_true)
# Sensitivity 0.5185185185185185
# Specificity 0.0
# F1-Score 0.6829268292682926
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.52      0.68        27
#
#     accuracy                           0.52        27
#    macro avg       0.50      0.26      0.34        27
# weighted avg       1.00      0.52      0.68        27
#
# -----------------
#
# Model: CatBoost (BorutaShap)
# Accuracy: 0.5185185185185185
# Precision: 1.0
# Average Precision: 1.0
# AUROC: N/A (Only 1 class in y_true)
# Sensitivity 0.5185185185185185
# Specificity 0.0
# F1-Score 0.6829268292682926
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.52      0.68        27
#
#     accuracy                           0.52        27
#    macro avg       0.50      0.26      0.34        27
# weighted avg       1.00      0.52      0.68        27
#
# -----------------
#
# Model: Random Forest (BorutaShap)
# Accuracy: 0.6296296296296297
# Precision: 1.0
# Average Precision: 1.0
# AUROC: N/A (Only 1 class in y_true)
# Sensitivity 0.6296296296296297
# Specificity 0.0
# F1-Score 0.7727272727272727
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.63      0.77        27
#
#     accuracy                           0.63        27
#    macro avg       0.50      0.31      0.39        27
# weighted avg       1.00      0.63      0.77        27
#
# -----------------

# %% [markdown]
# UNIMI

# %%
evaluate_all(bitter_models_full, X_train_bitter_subset, y_train_bitter, X_test_bitter_unimi_subset, y_test_bitter_unimi)
# Out:
# Model: XGBoost (BorutaShap)
# Accuracy: 0.75
# Precision: 0.6666666666666666
# Average Precision: 0.8208714464839438
# AUROC: 0.8656126482213438
# Sensitivity 0.782608695652174
# Specificity 0.7272727272727273
# F1-Score 0.72
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.83      0.73      0.77        33
#            1       0.67      0.78      0.72        23
#
#     accuracy                           0.75        56
#    macro avg       0.75      0.75      0.75        56
# weighted avg       0.76      0.75      0.75        56
#
# -----------------
#
# Model: CatBoost (BorutaShap)
# Accuracy: 0.7321428571428571
# Precision: 0.6428571428571429
# Average Precision: 0.7965308820871808
# AUROC: 0.8432147562582344
# Sensitivity 0.782608695652174
# Specificity 0.696969696969697
# F1-Score 0.7058823529411765
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.82      0.70      0.75        33
#            1       0.64      0.78      0.71        23
#
#     accuracy                           0.73        56
#    macro avg       0.73      0.74      0.73        56
# weighted avg       0.75      0.73      0.73        56
#
# -----------------
#
# Model: Random Forest (BorutaShap)
# Accuracy: 0.7321428571428571
# Precision: 0.6428571428571429
# Average Precision: 0.767005977344563
# AUROC: 0.8346508563899868
# Sensitivity 0.782608695652174
# Specificity 0.696969696969697
# F1-Score 0.7058823529411765
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.82      0.70      0.75        33
#            1       0.64      0.78      0.71        23
#
#     accuracy                           0.73        56
#    macro avg       0.73      0.74      0.73        56
# weighted avg       0.75      0.73      0.73        56
#
# -----------------
